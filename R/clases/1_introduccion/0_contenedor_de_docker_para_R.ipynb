# %% [markdown]
# # Contenedor de docker para Rstudio y Jupyterlab para Python y R
#
# Lo que se necesita para correr los ejemplos del propedéutico es:
#
# * Tener docker instalado en sus sistemas (ver [About Docker CE](https://docs.docker.com/install/)).
# * Elegir un directorio que se montará en el contenedor (la ruta al directorio de su elección **no** debe tener espacios o caracteres como acentos, si desean separar las palabras usen guiones).
# * Ejecutar lo siguiente:
#
#
# ## Contenedor de docker para Rstudio
#
# Modificar la variable en bash `dir_montar` de acuerdo al caso de cada persona.
#
#
# ```
# dir_montar=<ruta completa de mi máquina a mi directorio>#aquí colocar la ruta al directorio a montar, por ejemplo:
# #dir_montar=/Users/erick/midirectorio.
#
# PASSWORD=qwerty
#
#
# docker run --rm -d -p 8787:8787 -v $dir_montar:/home/rstudio/ --name rstudio-container -e PASSWORD=$PASSWORD rocker/rstudio:4.0.0-ubuntu18.04
# ```
#
# y vamos a un browser y colocamos:
#
# ```
# localhost:8787
# ```
#
# El password es `qwerty` con user `rstudio`.
#
# ## Jupyterlab + R y python3
#
#
# Modificar la variable en bash `dir_montar` de acuerdo al caso de cada persona.
#
# ```
# dir_montar=<ruta completa de mi máquina a mi directorio>#aquí colocar la ruta al directorio a montar, por ejemplo:
# #dir_montar=/Users/erick/midirectorio.
# ```
#
# Ejecutar:
#
# ```
# docker run --rm -v $dir_montar:/datos --name jupyterlab_prope_r_kernel_tidyverse -p 8888:8888 -d palmoreck/jupyterlab_prope_r_kernel_tidyverse:2.1.4
#
# ```
#
# y vamos a un browser y colocamos:
#
#     localhost:8888
#
# el password es `qwerty`.
#
# La documentación de la imagen de docker `palmoreck/jupyterlab_prope_r_kernel_tidyverse:2.1.4` la pueden encontrar [aquí](https://github.com/palmoreck/dockerfiles/tree/master/jupyterlab/prope_r_kernel_tidyverse)
#
#
# ## NOTA: Sistema Operativo Windows
#
# Revisar las instrucciones:
#
# * [install_docker_windows_home_10](https://github.com/ITAM-DS/Propedeutico/blob/master/herramientas/docker/install_docker_windows_home_10.md)
#
# * [install_docker_windows_MS_10](https://github.com/ITAM-DS/Propedeutico/blob/master/herramientas/docker/install_docker_windows_MS_10.md)

# %% [markdown]
# # Algunas referencias para docker:
#
# * [docker en repo de prope](https://github.com/ITAM-DS/Propedeutico/tree/master/herramientas/docker)
